# %% [markdown]
# # Gene Filtering (Protein Coding + HVG + DEG)
#
# **Input: ./data/pb_ct**
#
# **Output: ./data/pb_ct_filtered**

# %%
import sys
import os

# Add sources directory to sys.path
sys.path.append(os.path.abspath('../../sources'))

import gene_filtering

# Parameters
root_path = "../../data/"
gtf_path = f"{root_path}/Homo_sapiens.GRCh38.114.gtf.gz"
input_dir = f"{root_path}/primary_cohort/pb_ct"
output_dir = f"{root_path}/primary_cohort/pb_ct_filtered"

cell_types = ['astrocyte', 'microglia']
# Out:
# /data/home/swkim0523/.local/lib/python3.9/site-packages/setuptools_scm/version.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import iter_entry_points

# %%
# Run Gene Filtering
gene_filtering.main(
    gtf_path=gtf_path,
    cell_types=cell_types,
    input_dir=input_dir,
    output_dir=output_dir
)
# Out:
# Protein-coding IDs: 20,120, names: 19,450
#
# Processing Cell Type: astrocyte
# - Applying Protein Coding Gene Filter...
# # Genes after Protein Coding Gene Filter:17642, 17642
# - Applying Minimum Expression Filter...
# # Genes Min Expression CTRL:16319, SCZ:16344, Merged:16388
# # Genes after Minimum Expression Filter:16388, 16388
# - Applying HVG/DEG Filter...
# # Genes HVG/DEG CTRL_HVG:12291, SCZ_HVG:12291, Merged_HVG:12502
# # Genes DEG:2268
# -- # final filtered genes:12882 --
# Saved filtered data for astrocyte to /data/home/swkim0523/research/_SCZ_mic_ast_fin_0511/data/pb_ct_filtered
#
# Processing Cell Type: microglia
# - Applying Protein Coding Gene Filter...
# # Genes after Protein Coding Gene Filter:17642, 17642
# - Applying Minimum Expression Filter...
# # Genes Min Expression CTRL:14759, SCZ:14883, Merged:14940
# # Genes after Minimum Expression Filter:14940, 14940
# - Applying HVG/DEG Filter...
# # Genes HVG/DEG CTRL_HVG:11205, SCZ_HVG:11205, Merged_HVG:11499
# ...
